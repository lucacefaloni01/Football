# %% [markdown]
# # LIBRERIE

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import poisson 
from statistics import median
from matplotlib import pyplot

# %% [markdown]
# # DATI

# %% [markdown]
# # SerieA

# %%
###########SERIEA###########
SEA = pd.read_html("https://fbref.com/it/comp/11/Serie-A-Seasons#results2022-2023111_home_away::1")
for idx,table in enumerate(SEA):
    print('********')
    idx
    table
SerieA = SEA[0]
SerieA

print('OK!!')

#"#############ATALANTA#############"
Ata = pd.read_html("https://fbref.com/it/squadre/922493f3/Statistiche-Atalanta#matchlogs_for")
for idx,table in enumerate(Ata):
    print('********')
    idx
    table
Atalanta = Ata[1]
Atalanta = Atalanta[Atalanta['Rf'].notna()]
Atalanta
print('OK!!')
#"############BOLOGNA####################"
Bol = pd.read_html("https://fbref.com/it/squadre/1d8099f8/Statistiche-Bologna#matchlogs_for")
for idx,table in enumerate(Bol):
    print('********')
    idx
    table
Bologna = Bol[1]
Bologna = Bologna[Bologna['Rf'].notna()]
Bologna
print('OK!!')
##############CREMONESE##############
Cre = pd.read_html("https://fbref.com/it/squadre/9aad3a77/Statistiche-Cremonese#matchlogs_for")
for idx,table in enumerate(Cre):
    print('********')
    idx
    table
Cremonese = Cre[1]
Cremonese = Cremonese[Cremonese['Rf'].notna()]
Cremonese
print('OK!!')
#############EMPOLI################
Emp = pd.read_html("https://fbref.com/it/squadre/a3d88bd8/Statistiche-Empoli#matchlogs_for")
for idx,table in enumerate(Emp):
    print('********')
    idx
    table
Empoli = Emp[1]
Empoli = Empoli[Empoli['Rf'].notna()]
Empoli
print('OK!!')
###########Fiorentina###############
Fio = pd.read_html("https://fbref.com/it/squadre/421387cf/Statistiche-Fiorentina#matchlogs_for")
for idx,table in enumerate(Fio):
    print('********')
    idx
    table
Fiorentina = Fio[1]
Fiorentina = Fiorentina[Fiorentina['Rf'].notna()]
Fiorentina
print('OK!!')
#Hellas Verona ################

Hve = pd.read_html("https://fbref.com/it/squadre/0e72edf2/Statistiche-Hellas-Verona#stats_standard_11")
for idx,table in enumerate(Hve):
    print('********')
    idx
    table
HellasVerona = Hve[1]
HellasVerona = HellasVerona[HellasVerona['Rf'].notna()]
HellasVerona
print('OK!!')

#########Inter############

Int = pd.read_html("https://fbref.com/it/squadre/d609edc0/Statistiche-Internazionale#stats_standard_11")
for idx,table in enumerate(Int):
    print('********')
    idx
    table
Inter = Int[1]
Inter = Inter[Inter['Rf'].notna()]
Inter
print('OK!!')
########Juventus##########

Juv = pd.read_html("https://fbref.com/it/squadre/e0652b02/Statistiche-Juventus#stats_standard_11")
for idx,table in enumerate(Juv):
    print('********')
    idx
    table
Juve = Juv[1]
Juve = Juve[Juve['Rf'].notna()]
Juve
print('OK!!')
###########Lazio############
Laz = pd.read_html("https://fbref.com/it/squadre/7213da33/Statistiche-Lazio#matchlogs_for")
for idx,table in enumerate(Laz):
    print('********')
    idx
    table
Lazio = Laz[1]
Lazio = Lazio[Lazio['Rf'].notna()]
Lazio
print('OK!!')

##########Lecce#############
Lec = pd.read_html("https://fbref.com/it/squadre/ffcbe334/Statistiche-Lecce#stats_standard_11")
for idx,table in enumerate(Lec):
    print('********')
    idx
    table
Lecce = Lec[1]
Lecce = Lecce[Lecce['Rf'].notna()]
Lecce
print('OK!!')
##########Milan#############
Mil = pd.read_html("https://fbref.com/it/squadre/dc56fe14/Statistiche-Milan#matchlogs_for")
for idx,table in enumerate(Mil):
    print('********')
    idx
    table
Milan = Mil[1]
Milan = Milan[Milan['Rf'].notna()]
Milan
print('OK!!')
##########Monza#############
Mon = pd.read_html("https://fbref.com/it/squadre/21680aa4/Statistiche-Monza#stats_standard_11")
for idx,table in enumerate(Mon):
    print('********')
    idx
    table
Monza = Mon[1]
Monza = Monza[Monza['Rf'].notna()]
Monza
print('OK!!')
#########Napoli################

Nap = pd.read_html("https://fbref.com/it/squadre/d48ad4ff/Statistiche-Napoli#stats_standard_11")
for idx,table in enumerate(Nap):
    print('********')
    idx
    table
Napoli = Nap[1]
Napoli = Napoli[Napoli['Rf'].notna()]
Napoli
print('OK!!')
########Roma##################
Rom = pd.read_html("https://fbref.com/it/squadre/cf74a709/Statistiche-Roma#matchlogs_for")
for idx,table in enumerate(Rom):
    print('********')
    idx
    table
Roma = Rom[1]
Roma = Roma[Roma['Rf'].notna()]
Roma
print('OK!!')
#########Salernitana############
Sal = pd.read_html("https://fbref.com/it/squadre/c5577084/Statistiche-Salernitana#stats_standard_11")
for idx,table in enumerate(Sal):
    print('********')
    idx
    table
Salernitana = Sal[1]
Salernitana = Salernitana[Salernitana['Rf'].notna()]
Salernitana
print('OK!!')
########Sampdoria############
Sam = pd.read_html("https://fbref.com/it/squadre/8ff9e3b3/Statistiche-Sampdoria#matchlogs_for")
for idx,table in enumerate(Sam):
    print('********')
    idx
    table
Sampdoria = Sam[1]
Sampdoria = Sampdoria[Sampdoria['Rf'].notna()]
Sampdoria
print('OK!!')
###########Sassuolo###########
Sas = pd.read_html("https://fbref.com/it/squadre/e2befd26/Statistiche-Sassuolo#stats_standard_11")
for idx,table in enumerate(Sas):
    print('********')
    idx
    table
Sassuolo = Sas[1]
Sassuolo = Sassuolo[Sassuolo['Rf'].notna()]
Sassuolo
print('OK!!')
######Spezia############

Spe = pd.read_html("https://fbref.com/it/squadre/68449f6d/Statistiche-Spezia#stats_standard_11")
for idx,table in enumerate(Spe):
    print('********')
    idx
    table
Spezia = Spe[1]
Spezia = Spezia[Spezia['Rf'].notna()]
Spezia
print('OK!!')
########Torino#########
Tor = pd.read_html("https://fbref.com/it/squadre/105360fe/Statistiche-Torino#stats_standard_11")
for idx,table in enumerate(Tor):
    print('********')
    idx
    table
Torino = Tor[1]
Torino = Torino[Torino['Rf'].notna()]
Torino
print('OK!!')

#######Udinese##########
Udi = pd.read_html("https://fbref.com/it/squadre/04eea015/Statistiche-Udinese#stats_standard_11")
for idx,table in enumerate(Udi):
    print('********')
    idx
    table
Udinese = Udi[1]
Udinese = Udinese[Udinese['Rf'].notna()]
Udinese
print('OK!!')
# Out:
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# OK!!
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# OK!!
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# OK!!
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# OK!!
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# OK!!
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# OK!!
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# OK!!
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# OK!!
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# OK!!
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# OK!!
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# OK!!
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# OK!!
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# OK!!
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# OK!!
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# OK!!
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# OK!!
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# OK!!
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# OK!!
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# OK!!
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# OK!!
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# OK!!

# %%
#pulizia dataset
x = Sampdoria['Rf']
x = x.replace('2 (9)', '2')
Sampdoria['Rf'] = pd.Series(x).astype(float)

y = Sampdoria['Rs']
y = y.replace('2 (8)', '2')
Sampdoria['Rs'] = pd.Series(y).astype(float)
# Out:
# <ipython-input-24-3a1fc3f007de>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sampdoria['Rf'] = pd.Series(x).astype(float)
# <ipython-input-24-3a1fc3f007de>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sampdoria['Rs'] = pd.Series(y).astype(float)

# %% [markdown]
# # PremierLeague

# %%
#######Arsenal##########
Ars = pd.read_html("https://fbref.com/it/squadre/18bb7c10/Statistiche-Arsenal#stats_standard_9")
for idx,table in enumerate(Ars):
    print('********')
    idx
    table
Arsenal = Ars[1]
Arsenal = Arsenal[Arsenal['Rf'].notna()]
Arsenal

######AstonVilla##########
Asv = pd.read_html("https://fbref.com/it/squadre/8602292d/Statistiche-Aston-Villa#stats_standard_9")
for idx,table in enumerate(Asv):
    print('********')
    idx
    table
AstonVilla = Asv[1]
AstonVilla = AstonVilla[AstonVilla['Rf'].notna()]
AstonVilla

############Bournemouth##########
Bou = pd.read_html("https://fbref.com/it/squadre/4ba7cbea/Statistiche-Bournemouth#stats_standard_9")
for idx,table in enumerate(Bou):
    print('********')
    idx
    table
Bournemouth = Bou[1]
Bournemouth = Bournemouth[Bournemouth['Rf'].notna()]


#########Brentford##################
Bre = pd.read_html("https://fbref.com/it/squadre/cd051869/Statistiche-Brentford#stats_standard_9")
for idx,table in enumerate(Bre):
    print('********')
    idx
    table
Brentford = Bre[1]
Brentford = Brentford[Brentford['Rf'].notna()]


#############Brighton#################
Bri = pd.read_html("https://fbref.com/it/squadre/d07537b9/Statistiche-Brighton-and-Hove-Albion#stats_standard_9")
for idx,table in enumerate(Bre):
    print('********')
    idx
    table
Brighton = Bri[1]
Brighton = Brighton[Brighton['Rf'].notna()]




##########Chelsea#############
Che = pd.read_html("https://fbref.com/it/squadre/cff3d9bb/Statistiche-Chelsea#stats_standard_9")
for idx,table in enumerate(Che):
    print('********')
    idx
    table
Chelsea = Che[1]
Chelsea = Chelsea[Chelsea['Rf'].notna()]


##########Crystal Palace############
Crp = pd.read_html("https://fbref.com/it/squadre/47c64c55/Statistiche-Crystal-Palace#stats_standard_9")
for idx,table in enumerate(Crp):
    print('********')
    idx
    table
CrystalPalace = Crp[1]
CrystalPalace = CrystalPalace[CrystalPalace['Rf'].notna()]


##Everton#########
Eve = pd.read_html("https://fbref.com/it/squadre/d3fd31cc/Statistiche-Everton#stats_standard_9")
for idx,table in enumerate(Eve):
    print('********')
    idx
    table
Everton = Eve[1]
Everton = Everton[Everton['Rf'].notna()]




#############Fulham##########
Ful = pd.read_html("https://fbref.com/it/squadre/fd962109/Statistiche-Fulham#stats_standard_9")
for idx,table in enumerate(Ful):
    print('********')
    idx
    table
Fulham = Ful[1]
Fulham = Fulham[Fulham['Rf'].notna()]



############LeedsUnited#########
Leu = pd.read_html("https://fbref.com/it/squadre/5bfb9659/Statistiche-Leeds-United#stats_standard_9")
for idx,table in enumerate(Leu):
    print('********')
    idx
    table
LeedsUnited = Leu[1]
LeedsUnited = LeedsUnited[LeedsUnited['Rf'].notna()]




########Leicester City###########
Lec = pd.read_html("https://fbref.com/it/squadre/a2d435b3/Statistiche-Leicester-City#stats_standard_9")
for idx,table in enumerate(Lec):
    print('********')
    idx
    table
LeicesterCity = Lec[1]
LeicesterCity = LeicesterCity[LeicesterCity['Rf'].notna()]


##############Liverpool
Liv = pd.read_html("https://fbref.com/it/squadre/822bd0ba/Statistiche-Liverpool#stats_standard_9")
for idx,table in enumerate(Liv):
    print('********')
    idx
    table
Liverpool = Liv[1]
Liverpool = Liverpool[Liverpool['Rf'].notna()]




###########ManchesterCity
Mac = pd.read_html("https://fbref.com/it/squadre/b8fd03ef/Statistiche-Manchester-City#stats_standard_9")
for idx,table in enumerate(Mac):
    print('********')
    idx
    table
ManchesterCity = Mac[1]
ManchesterCity = ManchesterCity[ManchesterCity['Rf'].notna()]


#Manchester Utd
Mau = pd.read_html("https://fbref.com/it/squadre/19538871/Statistiche-Manchester-United#stats_standard_9")
for idx,table in enumerate(Mau):
    print('********')
    idx
    table
ManchesterUtd = Mau[1]
ManchesterUtd = ManchesterUtd[ManchesterUtd['Rf'].notna()]


#Newcastle Utd
Neu = pd.read_html("https://fbref.com/it/squadre/b2b47a98/Statistiche-Newcastle-United#stats_standard_9")
for idx,table in enumerate(Neu):
    print('********')
    idx
    table
NewcastleUtd = Neu[1]
NewcastleUtd = NewcastleUtd[NewcastleUtd['Rf'].notna()]


#Nott'hamForest
Nof = pd.read_html("https://fbref.com/it/squadre/e4a775cb/Statistiche-Nottingham-Forest#stats_standard_9")
for idx,table in enumerate(Nof):
    print('********')
    idx
    table
NotthamForest = Nof[1]
NotthamForest = NotthamForest[NotthamForest['Rf'].notna()]


#Southampton
Sou = pd.read_html("https://fbref.com/it/squadre/33c895d4/Statistiche-Southampton#stats_standard_9")
for idx,table in enumerate(Sou):
    print('********')
    idx
    table
Southampton = Sou[1]
Southampton = Southampton[Southampton['Rf'].notna()]


#Tottenham
Tot = pd.read_html("https://fbref.com/it/squadre/361ca564/Statistiche-Tottenham-Hotspur#stats_standard_9")
for idx,table in enumerate(Tot):
    print('********')
    idx
    table
Tottenham = Sou[1]
Tottenham = Tottenham[Tottenham['Rf'].notna()]

#WestHam
Weh = pd.read_html("https://fbref.com/it/squadre/7c21e445/Statistiche-West-Ham-United#stats_standard_9")
for idx,table in enumerate(Weh):
    print('********')
    idx
    table
WestHam = Weh[1]
WestHam = WestHam[WestHam['Rf'].notna()]

#Wolves
Wel = pd.read_html("https://fbref.com/it/squadre/8cec06e1/Statistiche-Wolverhampton-Wanderers#stats_standard_9")
for idx,table in enumerate(Wel):
    print('********')
    idx
    table
Wolves = Wel[1]
Wolves = Wolves[Wolves['Rf'].notna()]

# %%
#pulizia dataset
x = NewcastleUtd['Rf']
x = x.replace('0 (3)', '0')
NewcastleUtd['Rf'] = pd.Series(x).astype(float)

y = NewcastleUtd['Rs']
y = y.replace('0 (2)', '0')
NewcastleUtd['Rs'] = pd.Series(y).astype(float)

# %%
#pulizia dataset
x = Brighton['Rf']
x = x.replace('0 (3)', '0')
Brighton['Rf'] = pd.Series(x).astype(float)

y = Brighton['Rs']
y = y.replace('0 (4)', '0')
Brighton['Rs'] = pd.Series(y).astype(float)

# %%
#pulizia dataset
x = LeicesterCity['Rf']
x = x.replace('0 (3)', '0')
LeicesterCity['Rf'] = pd.Series(x).astype(float)

y = LeicesterCity['Rs']
y = y.replace('0 (1)', '0')
LeicesterCity['Rs'] = pd.Series(y).astype(float)

# %%
#pulizia dataset
x = Bournemouth['Rf']
x = x.replace('2 (5)', '2')
Bournemouth['Rf'] = pd.Series(x).astype(float)

y = Bournemouth['Rs']
y = y.replace('2 (3)', '2')
Bournemouth['Rs'] = pd.Series(y).astype(float)

# %%
#pulizia dataset
x = Brentford['Rf']
x = x.replace('1 (5)', '1')
Brentford['Rf'] = pd.Series(x).astype(float)

y = Brentford['Rs']
y = y.replace('1 (6)', '1')
Brentford['Rs'] = pd.Series(y).astype(float)

# %%
#pulizia dataset
x = Southampton['Rf']
x = x.replace('1 (6)', '1')
Southampton['Rf'] = pd.Series(x).astype(float)

y = Southampton['Rs']
y = y.replace('1 (5)', '1')
Southampton['Rs'] = pd.Series(y).astype(float)

# %%
#pulizia dataset
x = Liverpool['Rf']
x = x.replace('0 (3)', '0')
Liverpool['Rf'] = pd.Series(x).astype(float)

y = Liverpool['Rs']
y = y.replace('0 (2)', '0')
Liverpool['Rs'] = pd.Series(y).astype(float)

# %%
#pulizia dataset
x = WestHam['Rf']
x = x.replace('2 (9)', '2')
WestHam['Rf'] = pd.Series(x).astype(float)

y = WestHam['Rs']
y = y.replace('2 (10)', '2')
WestHam['Rs'] = pd.Series(y).astype(float)

# %%
#pulizia dataset
x = CrystalPalace['Rf']
x = x.replace('0 (2)', '0')
CrystalPalace['Rf'] = pd.Series(x).astype(float)

y = CrystalPalace['Rs']
y = y.replace('0 (3)', '0')
CrystalPalace['Rs'] = pd.Series(y).astype(float)

# %%
#pulizia dataset
x = Tottenham['Rf']
x = x.replace('1 (6)', '1')
Tottenham['Rf'] = pd.Series(x).astype(float)

y = Tottenham['Rs']
y = y.replace('1 (5)', '1')
Tottenham['Rs'] = pd.Series(y).astype(float)

# %% [markdown]
# # LaLiga

# %%
##Almería
Alm = pd.read_html("https://fbref.com/it/squadre/78ecf4bb/Statistiche-Almeria#stats_standard_12")
for idx,table in enumerate(Alm):
    print('********')
    idx
    table
Almeria = Alm[1]
Almeria = Almeria[Almeria['Rf'].notna()]


#Athletic Club
Ath = pd.read_html("https://fbref.com/it/squadre/2b390eca/Statistiche-Athletic-Club#stats_standard_12")
for idx,table in enumerate(Ath):
    print('********')
    idx
    table
AthleticClub = Ath[1]
AthleticClub = AthleticClub[AthleticClub['Rf'].notna()]

#Atlético Madrid
Atl = pd.read_html("https://fbref.com/it/squadre/db3b9613/Statistiche-Atletico-Madrid#stats_standard_12")
for idx,table in enumerate(Atl):
    print('********')
    idx
    table
AtleticoMadrid = Atl[1]
AtleticoMadrid = AtleticoMadrid[AtleticoMadrid['Rf'].notna()]

#Barcelona
Bar = pd.read_html("https://fbref.com/it/squadre/206d90db/Statistiche-Barcelona#stats_standard_12")
for idx,table in enumerate(Bar):
    print('********')
    idx
    table
Barcelona = Bar[1]
Barcelona = Barcelona[Barcelona['Rf'].notna()]

#Betis
Bet = pd.read_html("https://fbref.com/it/squadre/fc536746/Statistiche-Real-Betis#stats_standard_12")
for idx,table in enumerate(Bet):
    print('********')
    idx
    table
Betis = Bet[1]
Betis = Betis[Betis['Rf'].notna()]



#Cádiz
Cad = pd.read_html('https://fbref.com/it/squadre/ee7c297c/Statistiche-Cadiz#stats_standard_12')
for idx,table in enumerate(Cad):
    print('********')
    idx
    table
Cadiz = Cad[1]
Cadiz = Cadiz[Cadiz['Rf'].notna()]

#Celta Vigo
Cel = pd.read_html('https://fbref.com/it/squadre/f25da7fb/Statistiche-Celta-Vigo#stats_standard_12')
for idx,table in enumerate(Cel):
    print('********')
    idx
    table
CeltaVigo = Cel[1]
CeltaVigo = CeltaVigo[CeltaVigo['Rf'].notna()]


#Elche
Elc = pd.read_html('https://fbref.com/it/squadre/6c8b07df/Statistiche-Elche#stats_standard_12')
for idx,table in enumerate(Elc):
    print('********')
    idx
    table
Elche = Elc[1]
Elche = Elche[Elche['Rf'].notna()]


#Espanyol
Esp = pd.read_html('https://fbref.com/it/squadre/a8661628/Statistiche-Espanyol#stats_standard_12')
for idx,table in enumerate(Esp):
    print('********')
    idx
    table
Espanyol = Esp[1]
Espanyol = Espanyol[Espanyol['Rf'].notna()]


#Getafe
Get = pd.read_html('https://fbref.com/it/squadre/7848bd64/Statistiche-Getafe#stats_standard_12')
for idx,table in enumerate(Get):
    print('********')
    idx
    table
Getafe = Get[1]
Getafe = Getafe[Getafe['Rf'].notna()]

#Girona
Gir = pd.read_html('https://fbref.com/it/squadre/9024a00a/Statistiche-Girona#stats_standard_12')
for idx,table in enumerate(Gir):
    print('********')
    idx
    table
Girona = Gir[1]
Girona = Girona[Girona['Rf'].notna()]


#Mallorca
Mal = pd.read_html('https://fbref.com/it/squadre/2aa12281/Statistiche-Mallorca#stats_standard_12')
for idx,table in enumerate(Mal):
    print('********')
    idx
    table
Mallorca = Mal[1]
Mallorca = Mallorca[Mallorca['Rf'].notna()]

#Osasuna
Osa = pd.read_html('https://fbref.com/it/squadre/03c57e2b/Statistiche-Osasuna#stats_standard_12')
for idx,table in enumerate(Osa):
    print('********')
    idx
    table
Osasuna = Osa[1]
Osasuna = Osasuna[Osasuna['Rf'].notna()]

#Rayo Vallecano
Ray = pd.read_html('https://fbref.com/it/squadre/98e8af82/Statistiche-Rayo-Vallecano#stats_standard_12')
for idx,table in enumerate(Ray):
    print('********')
    idx
    table
RayoVallecano = Ray[1]
RayoVallecano = RayoVallecano[RayoVallecano['Rf'].notna()]


#Real Madrid
Rea = pd.read_html('https://fbref.com/it/squadre/53a2f082/Statistiche-Real-Madrid#stats_standard_12')
for idx,table in enumerate(Rea):
    print('********')
    idx
    table
RealMadrid = Rea[1]
RealMadrid = RealMadrid[RealMadrid['Rf'].notna()]

#Real Sociedad
Res = pd.read_html('https://fbref.com/it/squadre/e31d1cd9/Statistiche-Real-Sociedad#stats_standard_12')
for idx,table in enumerate(Res):
    print('********')
    idx
    table
RealSociedad = Res[1]
RealSociedad = RealSociedad[RealSociedad['Rf'].notna()]

#Sevilla
Sev = pd.read_html('https://fbref.com/it/squadre/ad2be733/Statistiche-Sevilla#stats_standard_12')
for idx,table in enumerate(Sev):
    print('********')
    idx
    table
Sevilla = Sev[1]
Sevilla = Sevilla[Sevilla['Rf'].notna()]

#Valencia
Val = pd.read_html('https://fbref.com/it/squadre/dcc91a7b/Statistiche-Valencia#stats_standard_12')
for idx,table in enumerate(Val):
    print('********')
    idx
    table
Valencia = Val[1]
Valencia = Valencia[Valencia['Rf'].notna()]

#Valladolid
Vad = pd.read_html('https://fbref.com/it/squadre/17859612/Statistiche-Valladolid#stats_standard_12')
for idx,table in enumerate(Vad):
    print('********')
    idx
    table
Valladolid = Vad[1]
Valladolid = Valladolid[Valladolid['Rf'].notna()]

#Villarreal
Vil = pd.read_html('https://fbref.com/it/squadre/2a8183b3/Statistiche-Villarreal#stats_standard_12')
for idx,table in enumerate(Vil):
    print('********')
    idx
    table
Villarreal = Vil[1]
Villarreal = Villarreal[Villarreal['Rf'].notna()]
# Out:
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********

# %%
#pulizia dataset
x = RayoVallecano['Rf']
x = x.replace('0 (3)', '0')
RayoVallecano['Rf'] = pd.Series(x).astype(float)

y = RayoVallecano['Rs']
y = y.replace('0 (1)', '0')
RayoVallecano['Rs'] = pd.Series(y).astype(float)
# Out:
# <ipython-input-12-2ace5485d88d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RayoVallecano['Rf'] = pd.Series(x).astype(float)
# <ipython-input-12-2ace5485d88d>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RayoVallecano['Rs'] = pd.Series(y).astype(float)

# %% [markdown]
# # Ligue1

# %% [markdown]
# # Bundesliga

# %% [markdown]
# # Grafici

# %%
def graph_diff(data1,data2):    
    from matplotlib import pyplot

    x = data1['Rf']
    y = data2['Rf']

    pyplot.hist(x, alpha=0.5, label='Casa')
    pyplot.hist(y, alpha=0.5, label='Trasferta')
    pyplot.legend(loc='upper right')
    pyplot.title("Reti Fatte")
    pyplot.show()

    z = data1['Rs']
    i = data2['Rs']

    pyplot.hist(z, alpha=0.5, label='Casa')
    pyplot.hist(i, alpha=0.5, label='Trasferta')
    pyplot.legend(loc='upper right')
    pyplot.title("Reti Subite")
    pyplot.show()
    
    
def freq(data1, data2):
    from matplotlib import pyplot
    freq_tabli = pd.crosstab(data1['Risultato'], 'n di esiti')
    op = ['N','P','V']
    plt.pie(freq_tabli['n di esiti'], labels=op , autopct='%1.1f%%')
    plt.title("Esiti Casa")
    plt.show()
    
    from matplotlib import pyplot
    freq_table = pd.crosstab(data2['Risultato'], 'n di esiti')
    op = ['N','P','V']
    plt.pie(freq_table['n di esiti'], labels=op , autopct='%1.1f%%')
    plt.title("Esiti Ospiti")
    plt.show()

# %% [markdown]
# # Funzioni

# %%
def unopuntozero(data1,data2):
    from statistics import median
    print("Mediana Casa")
    i_fatti = median(data1["Rf"])
    i_subiti = median(data1["Rs"])
    print("Fatti Casa: ",i_fatti)
    print("Subiti Casa: ",i_subiti)
    from statistics import median
    print("                      ")
    print("                      ")
    print("Mediana Ospiti")
    y_fatti = median(data2["Rf"])
    y_subiti = median(data2["Rs"])
    print("Fatti Ospiti",y_fatti)
    print("Subiti Ospiti",y_subiti)
    casa_dif = i_fatti - y_subiti 
    ospiti_dif = y_fatti - i_subiti 
    import numpy as np
    print("                      ")
    print('Diferenza tra fatti e subiti')
    risultato = np.array([[casa_dif, ospiti_dif]])
    print(risultato)
    
def irene2(data1, data2):
    from scipy.stats import poisson 
    from statistics import median
    i_fatti = median(data1["Rf"])
    i_subiti = median(data1["Rs"])
    y_fatti = median(data2["Rf"])
    y_subiti = median(data2["Rs"])
    # goals_scored * goals_conceded
    lamb_home = i_fatti * y_subiti
    lamb_away = y_fatti * i_subiti
    prob_home, prob_away, prob_draw = 0, 0, 0
    for x in range(0,5): #number of goals home team
        for y in range(0, 5): #number of goals away team
            p = poisson.pmf(x, lamb_home) * poisson.pmf(y, lamb_away)
            if x == y:
                prob_draw += p
            elif x > y:
                prob_home += p
            else:
                prob_away += p

    points_home = 3 * prob_home + prob_draw
    points_away = 3 * prob_away + prob_draw
    return (points_home, points_away)

# %%
def analisi(data1, data2):
    print("""                                                   
   (            (        (            (            
   )\      (    )\ )     )\           )\ )     (   
 (((_)    ))\  (()/(   (((_)    (    (()/(    ))\  
 )\___   /((_)  /(_))  )\___    )\    ((_))  /((_) 
((/ __| (_))   (_) _| ((/ __|  ((_)   _| |  (_))   
 | (__  / -_)   |  _|  | (__  / _ \ / _` |  / -_)  
  \___| \___|   |_|     \___| \___/ \__,_|  \___|  
    """)
    print("""

/$$      /$$           /$$                                            
| $$  /$ | $$          | $$                                            
| $$ /$$$| $$  /$$$$$$ | $$  /$$$$$$$  /$$$$$$  /$$$$$$/$$$$   /$$$$$$ 
| $$/$$ $$ $$ /$$__  $$| $$ /$$_____/ /$$__  $$| $$_  $$_  $$ /$$__  $$
| $$$$_  $$$$| $$$$$$$$| $$| $$      | $$  \ $$| $$ \ $$ \ $$| $$$$$$$$
| $$$/ \  $$$| $$_____/| $$| $$      | $$  | $$| $$ | $$ | $$| $$_____/
| $$/   \  $$|  $$$$$$$| $$|  $$$$$$$|  $$$$$$/| $$ | $$ | $$|  $$$$$$$
|__/     \__/ \_______/|__/ \_______/ \______/ |__/ |__/ |__/ \_______/


.___________. ______   
|           |/  __  \  
`---|  |----|  |  |  | 
    |  |    |  |  |  | 
    |  |    |  `--'  | 
    |__|     \______/  



 __  .______      _______ .__   __.  _______ ____          ___   
|  | |   _  \    |   ____||  \ |  | |   ____|___ \        / _ \  
|  | |  |_)  |   |  |__   |   \|  | |  |__    __) |      | | | | 
|  | |      /    |   __|  |  . `  | |   __|  |__ <       | | | | 
|  | |  |\  \----|  |____ |  |\   | |  |____ ___) |      | |_| | 
|__| | _| `._____|_______||__| \__| |_______|____/ ______ \___/  
                                                  |______|     
               

    """)
    
    
    print('*GRAFICI*')
    graph_diff(data1, data2)
    freq(data1, data2)
    print("                      ")
    unopuntozero(data1, data2)
    print("                      ")
    print('*Probabilità del numero di gol *')
    print(irene2(data1, data2))

# %% [markdown]
# ## Analisi SerieA

# %%
#Analsi 16 turno SerieA
print("Salernitana, Milan")
analisi(Salernitana, Milan)
print("Sassuolo, Sampdoria")
analisi(Sassuolo, Sampdoria)
print("Spezia, Atalanta")
analisi(Spezia, Atalanta)
print("Torino, HellasVerona")
analisi(Torino, HellasVerona)
print("Lecce, Lazio")
analisi(Lecce, Lazio)
print("Roma, Bologna")
analisi(Roma, Bologna)
print("Cremonese, Juve")
analisi(Cremonese, Juve)
print("Fiorentina, Monza")
analisi(Fiorentina, Monza)
print("Inter, Napoli")
analisi(Inter, Napoli)
print("Udinese, Empoli")
analisi(Udinese, Empoli)
# Out:
# Salernitana, Milan
#
#    (            (        (            (
#    )\      (    )\ )     )\           )\ )     (
#  (((_)    ))\  (()/(   (((_)    (    (()/(    ))\
#  )\___   /((_)  /(_))  )\___    )\    ((_))  /((_)
# ((/ __| (_))   (_) _| ((/ __|  ((_)   _| |  (_))
#  | (__  / -_)   |  _|  | (__  / _ \ / _` |  / -_)
#   \___| \___|   |_|     \___| \___/ \__,_|  \___|
#
#
#
# /$$      /$$           /$$
# | $$  /$ | $$          | $$
# | $$ /$$$| $$  /$$$$$$ | $$  /$$$$$$$  /$$$$$$  /$$$$$$/$$$$   /$$$$$$
# | $$/$$ $$ $$ /$$__  $$| $$ /$$_____/ /$$__  $$| $$_  $$_  $$ /$$__  $$
# | $$$$_  $$$$| $$$$$$$$| $$| $$      | $$  \ $$| $$ \ $$ \ $$| $$$$$$$$
# | $$$/ \  $$$| $$_____/| $$| $$      | $$  | $$| $$ | $$ | $$| $$_____/
# | $$/   \  $$|  $$$$$$$| $$|  $$$$$$$|  $$$$$$/| $$ | $$ | $$|  $$$$$$$
# |__/     \__/ \_______/|__/ \_______/ \______/ |__/ |__/ |__/ \_______/
#
#
# .___________. ______
# |           |/  __  \
# `---|  |----|  |  |  |
#     |  |    |  |  |  |
#     |  |    |  `--'  |
#     |__|     \______/
#
#
#
#  __  .______      _______ .__   __.  _______ ____          ___
# |  | |   _  \    |   ____||  \ |  | |   ____|___ \        / _ \
# |  | |  |_)  |   |  |__   |   \|  | |  |__    __) |      | | | |
# |  | |      /    |   __|  |  . `  | |   __|  |__ <       | | | |
# |  | |  |\  \----|  |____ |  |\   | |  |____ ___) |      | |_| |
# |__| | _| `._____|_______||__| \__| |_______|____/ ______ \___/
#                                                   |______|
#
#
#
# *GRAFICI*
# *Differenza della mediana statistica tra reti fatte e reti subite
# Mediana Casa
# Fatti Casa:  1.0
# Subiti Casa:  2.0
# Mediana Ospiti
# Fatti Ospiti 2.0
# Subiti Ospiti 1.0
# Diferenza tra fatti e subiti
# [[0. 0.]]
# *Probabilità del numero di gol *
# (0.21009293073537322, 1.593898795672551)
# Sassuolo, Sampdoria
#
#    (            (        (            (
#    )\      (    )\ )     )\           )\ )     (
#  (((_)    ))\  (()/(   (((_)    (    (()/(    ))\
#  )\___   /((_)  /(_))  )\___    )\    ((_))  /((_)
# ((/ __| (_))   (_) _| ((/ __|  ((_)   _| |  (_))
#  | (__  / -_)   |  _|  | (__  / _ \ / _` |  / -_)
#   \___| \___|   |_|     \___| \___/ \__,_|  \___|
#
#
#
# /$$      /$$           /$$
# | $$  /$ | $$          | $$
# | $$ /$$$| $$  /$$$$$$ | $$  /$$$$$$$  /$$$$$$  /$$$$$$/$$$$   /$$$$$$
# | $$/$$ $$ $$ /$$__  $$| $$ /$$_____/ /$$__  $$| $$_  $$_  $$ /$$__  $$
# | $$$$_  $$$$| $$$$$$$$| $$| $$      | $$  \ $$| $$ \ $$ \ $$| $$$$$$$$
# | $$$/ \  $$$| $$_____/| $$| $$      | $$  | $$| $$ | $$ | $$| $$_____/
# | $$/   \  $$|  $$$$$$$| $$|  $$$$$$$|  $$$$$$/| $$ | $$ | $$|  $$$$$$$
# |__/     \__/ \_______/|__/ \_______/ \______/ |__/ |__/ |__/ \_______/
#
#
# .___________. ______
# |           |/  __  \
# `---|  |----|  |  |  |
#     |  |    |  |  |  |
#     |  |    |  `--'  |
#     |__|     \______/
#
#
#
#  __  .______      _______ .__   __.  _______ ____          ___
# |  | |   _  \    |   ____||  \ |  | |   ____|___ \        / _ \
# |  | |  |_)  |   |  |__   |   \|  | |  |__    __) |      | | | |
# |  | |      /    |   __|  |  . `  | |   __|  |__ <       | | | |
# |  | |  |\  \----|  |____ |  |\   | |  |____ ___) |      | |_| |
# |__| | _| `._____|_______||__| \__| |_______|____/ ______ \___/
#                                                   |______|
#
#
#
# *GRAFICI*
# *Differenza della mediana statistica tra reti fatte e reti subite
# Mediana Casa
# Fatti Casa:  1.0
# Subiti Casa:  1.5
# Mediana Ospiti
# Fatti Ospiti 0.0
# Subiti Ospiti 2.0
# Diferenza tra fatti e subiti
# [[-1.  -1.5]]
# *Probabilità del numero di gol *
# (2.5713703814956412, 0.1353352832366127)
# Spezia, Atalanta
#
#    (            (        (            (
#    )\      (    )\ )     )\           )\ )     (
#  (((_)    ))\  (()/(   (((_)    (    (()/(    ))\
#  )\___   /((_)  /(_))  )\___    )\    ((_))  /((_)
# ((/ __| (_))   (_) _| ((/ __|  ((_)   _| |  (_))
#  | (__  / -_)   |  _|  | (__  / _ \ / _` |  / -_)
#   \___| \___|   |_|     \___| \___/ \__,_|  \___|
#
#
#
# /$$      /$$           /$$
# | $$  /$ | $$          | $$
# | $$ /$$$| $$  /$$$$$$ | $$  /$$$$$$$  /$$$$$$  /$$$$$$/$$$$   /$$$$$$
# | $$/$$ $$ $$ /$$__  $$| $$ /$$_____/ /$$__  $$| $$_  $$_  $$ /$$__  $$
# | $$$$_  $$$$| $$$$$$$$| $$| $$      | $$  \ $$| $$ \ $$ \ $$| $$$$$$$$
# | $$$/ \  $$$| $$_____/| $$| $$      | $$  | $$| $$ | $$ | $$| $$_____/
# | $$/   \  $$|  $$$$$$$| $$|  $$$$$$$|  $$$$$$/| $$ | $$ | $$|  $$$$$$$
# |__/     \__/ \_______/|__/ \_______/ \______/ |__/ |__/ |__/ \_______/
#
#
# .___________. ______
# |           |/  __  \
# `---|  |----|  |  |  |
#     |  |    |  |  |  |
#     |  |    |  `--'  |
#     |__|     \______/
#
#
#
#  __  .______      _______ .__   __.  _______ ____          ___
# |  | |   _  \    |   ____||  \ |  | |   ____|___ \        / _ \
# |  | |  |_)  |   |  |__   |   \|  | |  |__    __) |      | | | |
# |  | |      /    |   __|  |  . `  | |   __|  |__ <       | | | |
# |  | |  |\  \----|  |____ |  |\   | |  |____ ___) |      | |_| |
# |__| | _| `._____|_______||__| \__| |_______|____/ ______ \___/
#                                                   |______|
#
#
#
# *GRAFICI*
# *Differenza della mediana statistica tra reti fatte e reti subite
# Mediana Casa
# Fatti Casa:  1.0
# Subiti Casa:  2.0
# Mediana Ospiti
# Fatti Ospiti 1.0
# Subiti Ospiti 1.0
# Diferenza tra fatti e subiti
# [[ 0. -1.]]
# *Probabilità del numero di gol *
# (0.7488804866999538, 1.871163986158887)
# Torino, HellasVerona
#
#    (            (        (            (
#    )\      (    )\ )     )\           )\ )     (
#  (((_)    ))\  (()/(   (((_)    (    (()/(    ))\
#  )\___   /((_)  /(_))  )\___    )\    ((_))  /((_)
# ((/ __| (_))   (_) _| ((/ __|  ((_)   _| |  (_))
#  | (__  / -_)   |  _|  | (__  / _ \ / _` |  / -_)
#   \___| \___|   |_|     \___| \___/ \__,_|  \___|
#
#
#
# /$$      /$$           /$$
# | $$  /$ | $$          | $$
# | $$ /$$$| $$  /$$$$$$ | $$  /$$$$$$$  /$$$$$$  /$$$$$$/$$$$   /$$$$$$
# | $$/$$ $$ $$ /$$__  $$| $$ /$$_____/ /$$__  $$| $$_  $$_  $$ /$$__  $$
# | $$$$_  $$$$| $$$$$$$$| $$| $$      | $$  \ $$| $$ \ $$ \ $$| $$$$$$$$
# | $$$/ \  $$$| $$_____/| $$| $$      | $$  | $$| $$ | $$ | $$| $$_____/
# | $$/   \  $$|  $$$$$$$| $$|  $$$$$$$|  $$$$$$/| $$ | $$ | $$|  $$$$$$$
# |__/     \__/ \_______/|__/ \_______/ \______/ |__/ |__/ |__/ \_______/
#
#
# .___________. ______
# |           |/  __  \
# `---|  |----|  |  |  |
#     |  |    |  |  |  |
#     |  |    |  `--'  |
#     |__|     \______/
#
#
#
#  __  .______      _______ .__   __.  _______ ____          ___
# |  | |   _  \    |   ____||  \ |  | |   ____|___ \        / _ \
# |  | |  |_)  |   |  |__   |   \|  | |  |__    __) |      | | | |
# |  | |      /    |   __|  |  . `  | |   __|  |__ <       | | | |
# |  | |  |\  \----|  |____ |  |\   | |  |____ ___) |      | |_| |
# |__| | _| `._____|_______||__| \__| |_______|____/ ______ \___/
#                                                   |______|
#
#
#
# *GRAFICI*
# *Differenza della mediana statistica tra reti fatte e reti subite
# Mediana Casa
# Fatti Casa:  1.0
# Subiti Casa:  1.0
# Mediana Ospiti
# Fatti Ospiti 1.0
# Subiti Ospiti 2.0
# Diferenza tra fatti e subiti
# [[-1.  0.]]
# *Probabilità del numero di gol *
# (1.8711639861588865, 0.7488804866999538)
# Lecce, Lazio
#
#    (            (        (            (
#    )\      (    )\ )     )\           )\ )     (
#  (((_)    ))\  (()/(   (((_)    (    (()/(    ))\
#  )\___   /((_)  /(_))  )\___    )\    ((_))  /((_)
# ((/ __| (_))   (_) _| ((/ __|  ((_)   _| |  (_))
#  | (__  / -_)   |  _|  | (__  / _ \ / _` |  / -_)
#   \___| \___|   |_|     \___| \___/ \__,_|  \___|
#
#
#
# /$$      /$$           /$$
# | $$  /$ | $$          | $$
# | $$ /$$$| $$  /$$$$$$ | $$  /$$$$$$$  /$$$$$$  /$$$$$$/$$$$   /$$$$$$
# | $$/$$ $$ $$ /$$__  $$| $$ /$$_____/ /$$__  $$| $$_  $$_  $$ /$$__  $$
# | $$$$_  $$$$| $$$$$$$$| $$| $$      | $$  \ $$| $$ \ $$ \ $$| $$$$$$$$
# | $$$/ \  $$$| $$_____/| $$| $$      | $$  | $$| $$ | $$ | $$| $$_____/
# | $$/   \  $$|  $$$$$$$| $$|  $$$$$$$|  $$$$$$/| $$ | $$ | $$|  $$$$$$$
# |__/     \__/ \_______/|__/ \_______/ \______/ |__/ |__/ |__/ \_______/
#
#
# .___________. ______
# |           |/  __  \
# `---|  |----|  |  |  |
#     |  |    |  |  |  |
#     |  |    |  `--'  |
#     |__|     \______/
#
#
#
#  __  .______      _______ .__   __.  _______ ____          ___
# |  | |   _  \    |   ____||  \ |  | |   ____|___ \        / _ \
# |  | |  |_)  |   |  |__   |   \|  | |  |__    __) |      | | | |
# |  | |      /    |   __|  |  . `  | |   __|  |__ <       | | | |
# |  | |  |\  \----|  |____ |  |\   | |  |____ ___) |      | |_| |
# |__| | _| `._____|_______||__| \__| |_______|____/ ______ \___/
#                                                   |______|
#
#
#
# *GRAFICI*
# *Differenza della mediana statistica tra reti fatte e reti subite
# Mediana Casa
# Fatti Casa:  1.0
# Subiti Casa:  1.0
# Mediana Ospiti
# Fatti Ospiti 1.0
# Subiti Ospiti 1.0
# Diferenza tra fatti e subiti
# [[0. 0.]]
# *Probabilità del numero di gol *
# (1.3347912223388834, 1.3347912223388831)
# Roma, Bologna
#
#    (            (        (            (
#    )\      (    )\ )     )\           )\ )     (
#  (((_)    ))\  (()/(   (((_)    (    (()/(    ))\
#  )\___   /((_)  /(_))  )\___    )\    ((_))  /((_)
# ((/ __| (_))   (_) _| ((/ __|  ((_)   _| |  (_))
#  | (__  / -_)   |  _|  | (__  / _ \ / _` |  / -_)
#   \___| \___|   |_|     \___| \___/ \__,_|  \___|
#
#
#
# /$$      /$$           /$$
# | $$  /$ | $$          | $$
# | $$ /$$$| $$  /$$$$$$ | $$  /$$$$$$$  /$$$$$$  /$$$$$$/$$$$   /$$$$$$
# | $$/$$ $$ $$ /$$__  $$| $$ /$$_____/ /$$__  $$| $$_  $$_  $$ /$$__  $$
# | $$$$_  $$$$| $$$$$$$$| $$| $$      | $$  \ $$| $$ \ $$ \ $$| $$$$$$$$
# | $$$/ \  $$$| $$_____/| $$| $$      | $$  | $$| $$ | $$ | $$| $$_____/
# | $$/   \  $$|  $$$$$$$| $$|  $$$$$$$|  $$$$$$/| $$ | $$ | $$|  $$$$$$$
# |__/     \__/ \_______/|__/ \_______/ \______/ |__/ |__/ |__/ \_______/
#
#
# .___________. ______
# |           |/  __  \
# `---|  |----|  |  |  |
#     |  |    |  |  |  |
#     |  |    |  `--'  |
#     |__|     \______/
#
#
#
#  __  .______      _______ .__   __.  _______ ____          ___
# |  | |   _  \    |   ____||  \ |  | |   ____|___ \        / _ \
# |  | |  |_)  |   |  |__   |   \|  | |  |__    __) |      | | | |
# |  | |      /    |   __|  |  . `  | |   __|  |__ <       | | | |
# |  | |  |\  \----|  |____ |  |\   | |  |____ ___) |      | |_| |
# |__| | _| `._____|_______||__| \__| |_______|____/ ______ \___/
#                                                   |______|
#
#
#
# *GRAFICI*
# *Differenza della mediana statistica tra reti fatte e reti subite
# Mediana Casa
# Fatti Casa:  1.0
# Subiti Casa:  1.0
# Mediana Ospiti
# Fatti Ospiti 1.0
# Subiti Ospiti 1.0
# Diferenza tra fatti e subiti
# [[0. 0.]]
# *Probabilità del numero di gol *
# (1.3347912223388834, 1.3347912223388831)
# Cremonese, Juve
#
#    (            (        (            (
#    )\      (    )\ )     )\           )\ )     (
#  (((_)    ))\  (()/(   (((_)    (    (()/(    ))\
#  )\___   /((_)  /(_))  )\___    )\    ((_))  /((_)
# ((/ __| (_))   (_) _| ((/ __|  ((_)   _| |  (_))
#  | (__  / -_)   |  _|  | (__  / _ \ / _` |  / -_)
#   \___| \___|   |_|     \___| \___/ \__,_|  \___|
#
#
#
# /$$      /$$           /$$
# | $$  /$ | $$          | $$
# | $$ /$$$| $$  /$$$$$$ | $$  /$$$$$$$  /$$$$$$  /$$$$$$/$$$$   /$$$$$$
# | $$/$$ $$ $$ /$$__  $$| $$ /$$_____/ /$$__  $$| $$_  $$_  $$ /$$__  $$
# | $$$$_  $$$$| $$$$$$$$| $$| $$      | $$  \ $$| $$ \ $$ \ $$| $$$$$$$$
# | $$$/ \  $$$| $$_____/| $$| $$      | $$  | $$| $$ | $$ | $$| $$_____/
# | $$/   \  $$|  $$$$$$$| $$|  $$$$$$$|  $$$$$$/| $$ | $$ | $$|  $$$$$$$
# |__/     \__/ \_______/|__/ \_______/ \______/ |__/ |__/ |__/ \_______/
#
#
# .___________. ______
# |           |/  __  \
# `---|  |----|  |  |  |
#     |  |    |  |  |  |
#     |  |    |  `--'  |
#     |__|     \______/
#
#
#
#  __  .______      _______ .__   __.  _______ ____          ___
# |  | |   _  \    |   ____||  \ |  | |   ____|___ \        / _ \
# |  | |  |_)  |   |  |__   |   \|  | |  |__    __) |      | | | |
# |  | |      /    |   __|  |  . `  | |   __|  |__ <       | | | |
# |  | |  |\  \----|  |____ |  |\   | |  |____ ___) |      | |_| |
# |__| | _| `._____|_______||__| \__| |_______|____/ ______ \___/
#                                                   |______|
#
#
#
# *GRAFICI*
# *Differenza della mediana statistica tra reti fatte e reti subite
# Mediana Casa
# Fatti Casa:  1.0
# Subiti Casa:  2.0
# Mediana Ospiti
# Fatti Ospiti 1.0
# Subiti Ospiti 1.0
# Diferenza tra fatti e subiti
# [[ 0. -1.]]
# *Probabilità del numero di gol *
# (0.7488804866999538, 1.871163986158887)
# Fiorentina, Monza
#
#    (            (        (            (
#    )\      (    )\ )     )\           )\ )     (
#  (((_)    ))\  (()/(   (((_)    (    (()/(    ))\
#  )\___   /((_)  /(_))  )\___    )\    ((_))  /((_)
# ((/ __| (_))   (_) _| ((/ __|  ((_)   _| |  (_))
#  | (__  / -_)   |  _|  | (__  / _ \ / _` |  / -_)
#   \___| \___|   |_|     \___| \___/ \__,_|  \___|
#
#
#
# /$$      /$$           /$$
# | $$  /$ | $$          | $$
# | $$ /$$$| $$  /$$$$$$ | $$  /$$$$$$$  /$$$$$$  /$$$$$$/$$$$   /$$$$$$
# | $$/$$ $$ $$ /$$__  $$| $$ /$$_____/ /$$__  $$| $$_  $$_  $$ /$$__  $$
# | $$$$_  $$$$| $$$$$$$$| $$| $$      | $$  \ $$| $$ \ $$ \ $$| $$$$$$$$
# | $$$/ \  $$$| $$_____/| $$| $$      | $$  | $$| $$ | $$ | $$| $$_____/
# | $$/   \  $$|  $$$$$$$| $$|  $$$$$$$|  $$$$$$/| $$ | $$ | $$|  $$$$$$$
# |__/     \__/ \_______/|__/ \_______/ \______/ |__/ |__/ |__/ \_______/
#
#
# .___________. ______
# |           |/  __  \
# `---|  |----|  |  |  |
#     |  |    |  |  |  |
#     |  |    |  `--'  |
#     |__|     \______/
#
#
#
#  __  .______      _______ .__   __.  _______ ____          ___
# |  | |   _  \    |   ____||  \ |  | |   ____|___ \        / _ \
# |  | |  |_)  |   |  |__   |   \|  | |  |__    __) |      | | | |
# |  | |      /    |   __|  |  . `  | |   __|  |__ <       | | | |
# |  | |  |\  \----|  |____ |  |\   | |  |____ ___) |      | |_| |
# |__| | _| `._____|_______||__| \__| |_______|____/ ______ \___/
#                                                   |______|
#
#
#
# *GRAFICI*
# *Differenza della mediana statistica tra reti fatte e reti subite
# Mediana Casa
# Fatti Casa:  1.0
# Subiti Casa:  1.0
# Mediana Ospiti
# Fatti Ospiti 2.0
# Subiti Ospiti 1.0
# Diferenza tra fatti e subiti
# [[0. 1.]]
# *Probabilità del numero di gol *
# (0.7488804866999538, 1.871163986158887)
# Inter, Napoli
#
#    (            (        (            (
#    )\      (    )\ )     )\           )\ )     (
#  (((_)    ))\  (()/(   (((_)    (    (()/(    ))\
#  )\___   /((_)  /(_))  )\___    )\    ((_))  /((_)
# ((/ __| (_))   (_) _| ((/ __|  ((_)   _| |  (_))
#  | (__  / -_)   |  _|  | (__  / _ \ / _` |  / -_)
#   \___| \___|   |_|     \___| \___/ \__,_|  \___|
#
#
#
# /$$      /$$           /$$
# | $$  /$ | $$          | $$
# | $$ /$$$| $$  /$$$$$$ | $$  /$$$$$$$  /$$$$$$  /$$$$$$/$$$$   /$$$$$$
# | $$/$$ $$ $$ /$$__  $$| $$ /$$_____/ /$$__  $$| $$_  $$_  $$ /$$__  $$
# | $$$$_  $$$$| $$$$$$$$| $$| $$      | $$  \ $$| $$ \ $$ \ $$| $$$$$$$$
# | $$$/ \  $$$| $$_____/| $$| $$      | $$  | $$| $$ | $$ | $$| $$_____/
# | $$/   \  $$|  $$$$$$$| $$|  $$$$$$$|  $$$$$$/| $$ | $$ | $$|  $$$$$$$
# |__/     \__/ \_______/|__/ \_______/ \______/ |__/ |__/ |__/ \_______/
#
#
# .___________. ______
# |           |/  __  \
# `---|  |----|  |  |  |
#     |  |    |  |  |  |
#     |  |    |  `--'  |
#     |__|     \______/
#
#
#
#  __  .______      _______ .__   __.  _______ ____          ___
# |  | |   _  \    |   ____||  \ |  | |   ____|___ \        / _ \
# |  | |  |_)  |   |  |__   |   \|  | |  |__    __) |      | | | |
# |  | |      /    |   __|  |  . `  | |   __|  |__ <       | | | |
# |  | |  |\  \----|  |____ |  |\   | |  |____ ___) |      | |_| |
# |__| | _| `._____|_______||__| \__| |_______|____/ ______ \___/
#                                                   |______|
#
#
#
# *GRAFICI*
# *Differenza della mediana statistica tra reti fatte e reti subite
# Mediana Casa
# Fatti Casa:  2.0
# Subiti Casa:  1.0
# Mediana Ospiti
# Fatti Ospiti 3.0
# Subiti Ospiti 1.0
# Diferenza tra fatti e subiti
# [[1. 2.]]
# *Probabilità del numero di gol *
# (0.7698104446455145, 1.383805864937178)
# Udinese, Empoli
#
#    (            (        (            (
#    )\      (    )\ )     )\           )\ )     (
#  (((_)    ))\  (()/(   (((_)    (    (()/(    ))\
#  )\___   /((_)  /(_))  )\___    )\    ((_))  /((_)
# ((/ __| (_))   (_) _| ((/ __|  ((_)   _| |  (_))
#  | (__  / -_)   |  _|  | (__  / _ \ / _` |  / -_)
#   \___| \___|   |_|     \___| \___/ \__,_|  \___|
#
#
#
# /$$      /$$           /$$
# | $$  /$ | $$          | $$
# | $$ /$$$| $$  /$$$$$$ | $$  /$$$$$$$  /$$$$$$  /$$$$$$/$$$$   /$$$$$$
# | $$/$$ $$ $$ /$$__  $$| $$ /$$_____/ /$$__  $$| $$_  $$_  $$ /$$__  $$
# | $$$$_  $$$$| $$$$$$$$| $$| $$      | $$  \ $$| $$ \ $$ \ $$| $$$$$$$$
# | $$$/ \  $$$| $$_____/| $$| $$      | $$  | $$| $$ | $$ | $$| $$_____/
# | $$/   \  $$|  $$$$$$$| $$|  $$$$$$$|  $$$$$$/| $$ | $$ | $$|  $$$$$$$
# |__/     \__/ \_______/|__/ \_______/ \______/ |__/ |__/ |__/ \_______/
#
#
# .___________. ______
# |           |/  __  \
# `---|  |----|  |  |  |
#     |  |    |  |  |  |
#     |  |    |  `--'  |
#     |__|     \______/
#
#
#
#  __  .______      _______ .__   __.  _______ ____          ___
# |  | |   _  \    |   ____||  \ |  | |   ____|___ \        / _ \
# |  | |  |_)  |   |  |__   |   \|  | |  |__    __) |      | | | |
# |  | |      /    |   __|  |  . `  | |   __|  |__ <       | | | |
# |  | |  |\  \----|  |____ |  |\   | |  |____ ___) |      | |_| |
# |__| | _| `._____|_______||__| \__| |_______|____/ ______ \___/
#                                                   |______|
#
#
#
# *GRAFICI*
# *Differenza della mediana statistica tra reti fatte e reti subite
# Mediana Casa
# Fatti Casa:  2.0
# Subiti Casa:  1.0
# Mediana Ospiti
# Fatti Ospiti 1.0
# Subiti Ospiti 1.0
# Diferenza tra fatti e subiti
# [[1. 0.]]
# *Probabilità del numero di gol *
# (1.8711639861588865, 0.7488804866999538)

# %% [markdown]
# ## Analisi Premier

# %%
#Analisi 19 turno Premier
print("Arsenal NewCastleUtd")
analisi(Arsenal, NewcastleUtd)
analisi(Everton, Brighton)
analisi(LeicesterCity, Fulham)
analisi(ManchesterUtd, Bournemouth)
analisi(Southampton,NotthamForest)
analisi(LeedsUnited, WestHam)
analisi(AstonVilla, Wolves)
analisi(CrystalPalace, Tottenham)
analisi(Chelsea, ManchesterCity)

# %% [markdown]
# ## Analisi LaLiga

# %%
#Laliga
analisi(Almeria, RealSociedad)
analisi(RayoVallecano, Betis)
analisi(Sevilla, Getafe)
analisi(AtleticoMadrid, Barcelona)
analisi(AthleticClub, Osasuna)

# %%
analisi(Elche, CeltaVigo)
analisi(Valencia, Cadiz)
analisi(Villarreal, RealMadrid)
analisi(Mallorca, Valladolid)
analisi(Espanyol, Girona)

# %% [markdown]
# ## 07-gen-23

# %%
analisi(Villarreal, RealMadrid)
# Out:
#
#    (            (        (            (
#    )\      (    )\ )     )\           )\ )     (
#  (((_)    ))\  (()/(   (((_)    (    (()/(    ))\
#  )\___   /((_)  /(_))  )\___    )\    ((_))  /((_)
# ((/ __| (_))   (_) _| ((/ __|  ((_)   _| |  (_))
#  | (__  / -_)   |  _|  | (__  / _ \ / _` |  / -_)
#   \___| \___|   |_|     \___| \___/ \__,_|  \___|
#
#
#
# /$$      /$$           /$$
# | $$  /$ | $$          | $$
# | $$ /$$$| $$  /$$$$$$ | $$  /$$$$$$$  /$$$$$$  /$$$$$$/$$$$   /$$$$$$
# | $$/$$ $$ $$ /$$__  $$| $$ /$$_____/ /$$__  $$| $$_  $$_  $$ /$$__  $$
# | $$$$_  $$$$| $$$$$$$$| $$| $$      | $$  \ $$| $$ \ $$ \ $$| $$$$$$$$
# | $$$/ \  $$$| $$_____/| $$| $$      | $$  | $$| $$ | $$ | $$| $$_____/
# | $$/   \  $$|  $$$$$$$| $$|  $$$$$$$|  $$$$$$/| $$ | $$ | $$|  $$$$$$$
# |__/     \__/ \_______/|__/ \_______/ \______/ |__/ |__/ |__/ \_______/
#
#
# .___________. ______
# |           |/  __  \
# `---|  |----|  |  |  |
#     |  |    |  |  |  |
#     |  |    |  `--'  |
#     |__|     \______/
#
#
#
#  __  .______      _______ .__   __.  _______ ____          ___
# |  | |   _  \    |   ____||  \ |  | |   ____|___ \        / _ \
# |  | |  |_)  |   |  |__   |   \|  | |  |__    __) |      | | | |
# |  | |      /    |   __|  |  . `  | |   __|  |__ <       | | | |
# |  | |  |\  \----|  |____ |  |\   | |  |____ ___) |      | |_| |
# |__| | _| `._____|_______||__| \__| |_______|____/ ______ \___/
#                                                   |______|
#
#
#
# *GRAFICI*
#
# Mediana Casa
# Fatti Casa:  2.0
# Subiti Casa:  1.0
#
#
# Mediana Ospiti
# Fatti Ospiti 2.0
# Subiti Ospiti 1.0
#
# Diferenza tra fatti e subiti
# [[1. 1.]]
#
# *Probabilità del numero di gol *
# (1.243428373446287, 1.243428373446287)

# %%
analisi(Mallorca, Valladolid)
# Out:
#
#    (            (        (            (
#    )\      (    )\ )     )\           )\ )     (
#  (((_)    ))\  (()/(   (((_)    (    (()/(    ))\
#  )\___   /((_)  /(_))  )\___    )\    ((_))  /((_)
# ((/ __| (_))   (_) _| ((/ __|  ((_)   _| |  (_))
#  | (__  / -_)   |  _|  | (__  / _ \ / _` |  / -_)
#   \___| \___|   |_|     \___| \___/ \__,_|  \___|
#
#
#
# /$$      /$$           /$$
# | $$  /$ | $$          | $$
# | $$ /$$$| $$  /$$$$$$ | $$  /$$$$$$$  /$$$$$$  /$$$$$$/$$$$   /$$$$$$
# | $$/$$ $$ $$ /$$__  $$| $$ /$$_____/ /$$__  $$| $$_  $$_  $$ /$$__  $$
# | $$$$_  $$$$| $$$$$$$$| $$| $$      | $$  \ $$| $$ \ $$ \ $$| $$$$$$$$
# | $$$/ \  $$$| $$_____/| $$| $$      | $$  | $$| $$ | $$ | $$| $$_____/
# | $$/   \  $$|  $$$$$$$| $$|  $$$$$$$|  $$$$$$/| $$ | $$ | $$|  $$$$$$$
# |__/     \__/ \_______/|__/ \_______/ \______/ |__/ |__/ |__/ \_______/
#
#
# .___________. ______
# |           |/  __  \
# `---|  |----|  |  |  |
#     |  |    |  |  |  |
#     |  |    |  `--'  |
#     |__|     \______/
#
#
#
#  __  .______      _______ .__   __.  _______ ____          ___
# |  | |   _  \    |   ____||  \ |  | |   ____|___ \        / _ \
# |  | |  |_)  |   |  |__   |   \|  | |  |__    __) |      | | | |
# |  | |      /    |   __|  |  . `  | |   __|  |__ <       | | | |
# |  | |  |\  \----|  |____ |  |\   | |  |____ ___) |      | |_| |
# |__| | _| `._____|_______||__| \__| |_______|____/ ______ \___/
#                                                   |______|
#
#
#
# *GRAFICI*
# *Differenza della mediana statistica tra reti fatte e reti subite
# Mediana Casa
# Fatti Casa:  1.0
# Subiti Casa:  1.0
# Mediana Ospiti
# Fatti Ospiti 0.5
# Subiti Ospiti 1.0
# Diferenza tra fatti e subiti
# [[ 0.  -0.5]]
# *Probabilità del numero di gol *
# (1.7480708217097205, 0.8909953367645798)

# %%
analisi(Espanyol, Girona)
# Out:
#
#    (            (        (            (
#    )\      (    )\ )     )\           )\ )     (
#  (((_)    ))\  (()/(   (((_)    (    (()/(    ))\
#  )\___   /((_)  /(_))  )\___    )\    ((_))  /((_)
# ((/ __| (_))   (_) _| ((/ __|  ((_)   _| |  (_))
#  | (__  / -_)   |  _|  | (__  / _ \ / _` |  / -_)
#   \___| \___|   |_|     \___| \___/ \__,_|  \___|
#
#
#
# /$$      /$$           /$$
# | $$  /$ | $$          | $$
# | $$ /$$$| $$  /$$$$$$ | $$  /$$$$$$$  /$$$$$$  /$$$$$$/$$$$   /$$$$$$
# | $$/$$ $$ $$ /$$__  $$| $$ /$$_____/ /$$__  $$| $$_  $$_  $$ /$$__  $$
# | $$$$_  $$$$| $$$$$$$$| $$| $$      | $$  \ $$| $$ \ $$ \ $$| $$$$$$$$
# | $$$/ \  $$$| $$_____/| $$| $$      | $$  | $$| $$ | $$ | $$| $$_____/
# | $$/   \  $$|  $$$$$$$| $$|  $$$$$$$|  $$$$$$/| $$ | $$ | $$|  $$$$$$$
# |__/     \__/ \_______/|__/ \_______/ \______/ |__/ |__/ |__/ \_______/
#
#
# .___________. ______
# |           |/  __  \
# `---|  |----|  |  |  |
#     |  |    |  |  |  |
#     |  |    |  `--'  |
#     |__|     \______/
#
#
#
#  __  .______      _______ .__   __.  _______ ____          ___
# |  | |   _  \    |   ____||  \ |  | |   ____|___ \        / _ \
# |  | |  |_)  |   |  |__   |   \|  | |  |__    __) |      | | | |
# |  | |      /    |   __|  |  . `  | |   __|  |__ <       | | | |
# |  | |  |\  \----|  |____ |  |\   | |  |____ ___) |      | |_| |
# |__| | _| `._____|_______||__| \__| |_______|____/ ______ \___/
#                                                   |______|
#
#
#
# *GRAFICI*
# *Differenza della mediana statistica tra reti fatte e reti subite
# Mediana Casa
# Fatti Casa:  1.0
# Subiti Casa:  1.0
# Mediana Ospiti
# Fatti Ospiti 1.0
# Subiti Ospiti 1.0
# Diferenza tra fatti e subiti
# [[0. 0.]]
# *Probabilità del numero di gol *
# (1.3347912223388834, 1.3347912223388831)

# %%
analisi(Fiorentina, Sassuolo)
# Out:
#
#    (            (        (            (
#    )\      (    )\ )     )\           )\ )     (
#  (((_)    ))\  (()/(   (((_)    (    (()/(    ))\
#  )\___   /((_)  /(_))  )\___    )\    ((_))  /((_)
# ((/ __| (_))   (_) _| ((/ __|  ((_)   _| |  (_))
#  | (__  / -_)   |  _|  | (__  / _ \ / _` |  / -_)
#   \___| \___|   |_|     \___| \___/ \__,_|  \___|
#
#
#
# /$$      /$$           /$$
# | $$  /$ | $$          | $$
# | $$ /$$$| $$  /$$$$$$ | $$  /$$$$$$$  /$$$$$$  /$$$$$$/$$$$   /$$$$$$
# | $$/$$ $$ $$ /$$__  $$| $$ /$$_____/ /$$__  $$| $$_  $$_  $$ /$$__  $$
# | $$$$_  $$$$| $$$$$$$$| $$| $$      | $$  \ $$| $$ \ $$ \ $$| $$$$$$$$
# | $$$/ \  $$$| $$_____/| $$| $$      | $$  | $$| $$ | $$ | $$| $$_____/
# | $$/   \  $$|  $$$$$$$| $$|  $$$$$$$|  $$$$$$/| $$ | $$ | $$|  $$$$$$$
# |__/     \__/ \_______/|__/ \_______/ \______/ |__/ |__/ |__/ \_______/
#
#
# .___________. ______
# |           |/  __  \
# `---|  |----|  |  |  |
#     |  |    |  |  |  |
#     |  |    |  `--'  |
#     |__|     \______/
#
#
#
#  __  .______      _______ .__   __.  _______ ____          ___
# |  | |   _  \    |   ____||  \ |  | |   ____|___ \        / _ \
# |  | |  |_)  |   |  |__   |   \|  | |  |__    __) |      | | | |
# |  | |      /    |   __|  |  . `  | |   __|  |__ <       | | | |
# |  | |  |\  \----|  |____ |  |\   | |  |____ ___) |      | |_| |
# |__| | _| `._____|_______||__| \__| |_______|____/ ______ \___/
#                                                   |______|
#
#
#
# *GRAFICI*
#
# Mediana Casa
# Fatti Casa:  1.0
# Subiti Casa:  1.0
#
#
# Mediana Ospiti
# Fatti Ospiti 1.0
# Subiti Ospiti 2.0
#
# Diferenza tra fatti e subiti
# [[-1.  0.]]
#
# *Probabilità del numero di gol *
# (1.8711639861588865, 0.7488804866999538)

# %%
analisi(Juve, Udinese)
# Out:
#
#    (            (        (            (
#    )\      (    )\ )     )\           )\ )     (
#  (((_)    ))\  (()/(   (((_)    (    (()/(    ))\
#  )\___   /((_)  /(_))  )\___    )\    ((_))  /((_)
# ((/ __| (_))   (_) _| ((/ __|  ((_)   _| |  (_))
#  | (__  / -_)   |  _|  | (__  / _ \ / _` |  / -_)
#   \___| \___|   |_|     \___| \___/ \__,_|  \___|
#
#
#
# /$$      /$$           /$$
# | $$  /$ | $$          | $$
# | $$ /$$$| $$  /$$$$$$ | $$  /$$$$$$$  /$$$$$$  /$$$$$$/$$$$   /$$$$$$
# | $$/$$ $$ $$ /$$__  $$| $$ /$$_____/ /$$__  $$| $$_  $$_  $$ /$$__  $$
# | $$$$_  $$$$| $$$$$$$$| $$| $$      | $$  \ $$| $$ \ $$ \ $$| $$$$$$$$
# | $$$/ \  $$$| $$_____/| $$| $$      | $$  | $$| $$ | $$ | $$| $$_____/
# | $$/   \  $$|  $$$$$$$| $$|  $$$$$$$|  $$$$$$/| $$ | $$ | $$|  $$$$$$$
# |__/     \__/ \_______/|__/ \_______/ \______/ |__/ |__/ |__/ \_______/
#
#
# .___________. ______
# |           |/  __  \
# `---|  |----|  |  |  |
#     |  |    |  |  |  |
#     |  |    |  `--'  |
#     |__|     \______/
#
#
#
#  __  .______      _______ .__   __.  _______ ____          ___
# |  | |   _  \    |   ____||  \ |  | |   ____|___ \        / _ \
# |  | |  |_)  |   |  |__   |   \|  | |  |__    __) |      | | | |
# |  | |      /    |   __|  |  . `  | |   __|  |__ <       | | | |
# |  | |  |\  \----|  |____ |  |\   | |  |____ ___) |      | |_| |
# |__| | _| `._____|_______||__| \__| |_______|____/ ______ \___/
#                                                   |______|
#
#
#
# *GRAFICI*
#
# Mediana Casa
# Fatti Casa:  1.0
# Subiti Casa:  0.5
#
#
# Mediana Ospiti
# Fatti Ospiti 2.0
# Subiti Ospiti 1.0
#
# Diferenza tra fatti e subiti
# [[0.  1.5]]
#
# *Probabilità del numero di gol *
# (1.3347912223388834, 1.3347912223388831)

# %%
analisi(Monza, Inter)
# Out:
#
#    (            (        (            (
#    )\      (    )\ )     )\           )\ )     (
#  (((_)    ))\  (()/(   (((_)    (    (()/(    ))\
#  )\___   /((_)  /(_))  )\___    )\    ((_))  /((_)
# ((/ __| (_))   (_) _| ((/ __|  ((_)   _| |  (_))
#  | (__  / -_)   |  _|  | (__  / _ \ / _` |  / -_)
#   \___| \___|   |_|     \___| \___/ \__,_|  \___|
#
#
#
# /$$      /$$           /$$
# | $$  /$ | $$          | $$
# | $$ /$$$| $$  /$$$$$$ | $$  /$$$$$$$  /$$$$$$  /$$$$$$/$$$$   /$$$$$$
# | $$/$$ $$ $$ /$$__  $$| $$ /$$_____/ /$$__  $$| $$_  $$_  $$ /$$__  $$
# | $$$$_  $$$$| $$$$$$$$| $$| $$      | $$  \ $$| $$ \ $$ \ $$| $$$$$$$$
# | $$$/ \  $$$| $$_____/| $$| $$      | $$  | $$| $$ | $$ | $$| $$_____/
# | $$/   \  $$|  $$$$$$$| $$|  $$$$$$$|  $$$$$$/| $$ | $$ | $$|  $$$$$$$
# |__/     \__/ \_______/|__/ \_______/ \______/ |__/ |__/ |__/ \_______/
#
#
# .___________. ______
# |           |/  __  \
# `---|  |----|  |  |  |
#     |  |    |  |  |  |
#     |  |    |  `--'  |
#     |__|     \______/
#
#
#
#  __  .______      _______ .__   __.  _______ ____          ___
# |  | |   _  \    |   ____||  \ |  | |   ____|___ \        / _ \
# |  | |  |_)  |   |  |__   |   \|  | |  |__    __) |      | | | |
# |  | |      /    |   __|  |  . `  | |   __|  |__ <       | | | |
# |  | |  |\  \----|  |____ |  |\   | |  |____ ___) |      | |_| |
# |__| | _| `._____|_______||__| \__| |_______|____/ ______ \___/
#                                                   |______|
#
#
#
# *GRAFICI*
# *Differenza della mediana statistica tra reti fatte e reti subite
# Mediana Casa
# Fatti Casa:  1.0
# Subiti Casa:  1.5
# Mediana Ospiti
# Fatti Ospiti 2.0
# Subiti Ospiti 1.0
# Diferenza tra fatti e subiti
# [[0.  0.5]]
# *Probabilità del numero di gol *
# (0.40323023740978853, 1.9028231714248995)

# %%
Monza
# Out:
#           Data    Ora  Competizione          Girone Giorno  Stadio Risultato  \
# 0   13-08-2022  18:30       Serie A   Giornata n. 1    Sab    Casa         V
# 1   21-08-2022  20:45       Serie A   Giornata n. 2    Dom  Ospiti         N
# 2   27-08-2022  20:45       Serie A   Giornata n. 3    Sab    Casa         V
# 3   30-08-2022  18:30       Serie A   Giornata n. 4    Mar  Ospiti         N
# 4   03-09-2022  18:00       Serie A   Giornata n. 5    Sab    Casa         V
# 5   06-09-2022  21:00  Champions Lg   Fase a gironi    Mar  Ospiti         N
# 6   10-09-2022  20:45       Serie A   Giornata n. 6    Sab  Ospiti         V
# 7   14-09-2022  18:45  Champions Lg   Fase a gironi    Mer    Casa         V
# 8   18-09-2022  20:45       Serie A   Giornata n. 7    Dom    Casa         P
# 9   01-10-2022  20:45       Serie A   Giornata n. 8    Sab  Ospiti         V
# 10  05-10-2022  20:00  Champions Lg   Fase a gironi    Mer  Ospiti         P
# 11  08-10-2022  18:00       Serie A   Giornata n. 9    Sab    Casa         V
# 12  11-10-2022  21:00  Champions Lg   Fase a gironi    Mar    Casa         P
# 13  16-10-2022  20:45       Serie A  Giornata n. 10    Dom  Ospiti         V
# 14  22-10-2022  18:00       Serie A  Giornata n. 11    Sab    Casa         V
# 15  25-10-2022  21:00  Champions Lg   Fase a gironi    Mar  Ospiti         V
# 16  30-10-2022  20:45       Serie A  Giornata n. 12    Dom  Ospiti         P
# 17  02-11-2022  21:00  Champions Lg   Fase a gironi    Mer    Casa         V
# 18  05-11-2022  20:45       Serie A  Giornata n. 13    Sab    Casa         V
# 19  08-11-2022  20:45       Serie A  Giornata n. 14    Mar  Ospiti         N
# 20  13-11-2022  18:00       Serie A  Giornata n. 15    Dom    Casa         V
# 21  04-01-2023  12:30       Serie A  Giornata n. 16    Mer  Ospiti         V
#
#      Rf   Rs        Avversario   xG  xGA  Poss.  Spettatori         Capitano  \
# 0   4.0  2.0           Udinese  2.3  0.5   59.0      70.197  Davide Calabria
# 1   1.0  1.0          Atalanta  1.3  0.5   60.0      19.216  Davide Calabria
# 2   2.0  0.0           Bologna  1.9  0.5   48.0      70.430  Davide Calabria
# 3   0.0  0.0          Sassuolo  0.7  1.1   62.0      18.053   Theo Hernández
# 4   3.0  2.0             Inter  1.3  1.8   47.0      75.475  Davide Calabria
# 5   1.0  1.0    at RB Salzburg  0.9  1.3   65.0      29.520  Davide Calabria
# 6   2.0  1.0         Sampdoria  1.7  0.7   43.0      23.049  Davide Calabria
# 7   3.0  1.0  hr Dinamo Zagreb  2.2  0.4   57.0      61.341  Davide Calabria
# 8   1.0  2.0            Napoli  2.6  1.4   51.0      72.573  Davide Calabria
# 9   3.0  1.0            Empoli  2.3  1.1   57.0      15.497  Davide Calabria
# 10  0.0  3.0       eng Chelsea  0.4  1.1   49.0      39.537  Ismaël Bennacer
# 11  2.0  0.0          Juventus  2.2  0.8   40.0      75.530   Theo Hernández
# 12  0.0  2.0       eng Chelsea  0.4  2.2   31.0      75.051   Theo Hernández
# 13  2.0  1.0     Hellas Verona  1.9  2.1   54.0      22.904   Theo Hernández
# 14  4.0  1.0             Monza  1.1  1.2   49.0      72.938   Theo Hernández
# 15  4.0  0.0  hr Dinamo Zagreb  3.2  0.7   45.0      20.572   Theo Hernández
# 16  1.0  2.0            Torino  1.1  0.6   56.0      26.133   Theo Hernández
# 17  4.0  0.0    at RB Salzburg  1.8  1.6   48.0      74.292   Theo Hernández
# 18  2.0  1.0            Spezia  2.2  1.6   58.0      71.099   Theo Hernández
# 19  0.0  0.0         Cremonese  1.0  0.3   71.0      14.610  Ismaël Bennacer
# 20  2.0  1.0        Fiorentina  1.5  0.5   50.0      73.007   Theo Hernández
# 21  2.0  1.0       Salernitana  2.7  0.7   56.0         NaN  Davide Calabria
#
#    Formazione               Arbitro  Report partita Note
# 0     4-2-3-1       Livio Marinelli  Report partita  NaN
# 1     4-2-3-1         Fabio Maresca  Report partita  NaN
# 2     4-2-3-1  Gianluca Manganiello  Report partita  NaN
# 3     4-2-3-1      Giovanni Ayroldi  Report partita  NaN
# 4     4-2-3-1        Daniele Chiffi  Report partita  NaN
# 5     4-2-3-1       Srđan Jovanović  Report partita  NaN
# 6     4-2-3-1        Michael Fabbri  Report partita  NaN
# 7     4-2-3-1             Jesús Gil  Report partita  NaN
# 8     4-2-3-1      Maurizio Mariani  Report partita  NaN
# 9     4-2-3-1    Gianluca Aureliano  Report partita  NaN
# 10    4-2-3-1        Danny Makkelie  Report partita  NaN
# 11    4-3-2-1        Daniele Orsato  Report partita  NaN
# 12    4-2-3-1        Daniel Siebert  Report partita  NaN
# 13    4-2-3-1          Davide Massa  Report partita  NaN
# 14    4-2-3-1       Livio Marinelli  Report partita  NaN
# 15    4-2-3-1      Szymon Marciniak  Report partita  NaN
# 16    4-2-3-1        Rosario Abisso  Report partita  NaN
# 17    4-2-3-1   Antonio Matéu Lahoz  Report partita  NaN
# 18    4-2-3-1        Michael Fabbri  Report partita  NaN
# 19    3-4-1-2       Antonio Rapuano  Report partita  NaN
# 20    4-2-3-1          Simone Sozza  Report partita  NaN
# 21    4-2-3-1    Francesco Fourneau  Report partita  NaN
